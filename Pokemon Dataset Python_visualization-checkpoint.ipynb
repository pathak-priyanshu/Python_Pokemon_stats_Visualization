# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:/Users/PRIYANSHU/Downloads/pokemon_data.csv")

# %%
df.head(10)
# Out:
#    dexnum        name  generation  type1   type2              species  height  \
# 0       1   Bulbasaur           1  Grass  Poison         Seed Pokémon     0.7
# 1       2     Ivysaur           1  Grass  Poison         Seed Pokémon     1.0
# 2       3    Venusaur           1  Grass  Poison         Seed Pokémon     2.0
# 3       4  Charmander           1   Fire     NaN       Lizard Pokémon     0.6
# 4       5  Charmeleon           1   Fire     NaN        Flame Pokémon     1.1
# 5       6   Charizard           1   Fire  Flying        Flame Pokémon     1.7
# 6       7    Squirtle           1  Water     NaN  Tiny Turtle Pokémon     0.5
# 7       8   Wartortle           1  Water     NaN       Turtle Pokémon     1.0
# 8       9   Blastoise           1  Water     NaN    Shellfish Pokémon     1.6
# 9      10    Caterpie           1    Bug     NaN         Worm Pokémon     0.3
#
#    weight     ability1     ability2  ... catch_rate  base_friendship  \
# 0     6.9     Overgrow  Chlorophyll  ...         45               50
# 1    13.0     Overgrow  Chlorophyll  ...         45               50
# 2   100.0     Overgrow  Chlorophyll  ...         45               50
# 3     8.5        Blaze  Solar Power  ...         45               50
# 4    19.0        Blaze  Solar Power  ...         45               50
# 5    90.5        Blaze  Solar Power  ...         45               50
# 6     9.0      Torrent    Rain Dish  ...         45               50
# 7    22.5      Torrent    Rain Dish  ...         45               50
# 8    85.5      Torrent    Rain Dish  ...         45               50
# 9     2.9  Shield Dust     Run Away  ...        255               50
#
#    base_exp  growth_rate  egg_group1  egg_group2  percent_male  \
# 0        64  Medium Slow      Grass      Monster          87.5
# 1       142  Medium Slow      Grass      Monster          87.5
# 2       236  Medium Slow      Grass      Monster          87.5
# 3        62  Medium Slow     Dragon      Monster          87.5
# 4       142  Medium Slow     Dragon      Monster          87.5
# 5       267  Medium Slow     Dragon      Monster          87.5
# 6        63  Medium Slow    Monster      Water 1          87.5
# 7       142  Medium Slow    Monster      Water 1          87.5
# 8       239  Medium Slow    Monster      Water 1          87.5
# 9        39  Medium Fast         Bug         NaN          50.0
#
#    percent_female egg_cycles  special_group
# 0            12.5         20       Ordinary
# 1            12.5         20       Ordinary
# 2            12.5         20       Ordinary
# 3            12.5         20       Ordinary
# 4            12.5         20       Ordinary
# 5            12.5         20       Ordinary
# 6            12.5         20       Ordinary
# 7            12.5         20       Ordinary
# 8            12.5         20       Ordinary
# 9            50.0         15       Ordinary
#
# [10 rows x 29 columns]

# %% [markdown]
# ### Meta data inspection(data about the data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   dexnum           1025 non-null   int64
#  1   name             1025 non-null   object
#  2   generation       1025 non-null   int64
#  3   type1            1025 non-null   object
#  4   type2            526 non-null    object
#  5   species          1025 non-null   object
#  6   height           1025 non-null   float64
#  7   weight           1025 non-null   float64
#  8   ability1         1025 non-null   object
#  9   ability2         858 non-null    object
#  10  hidden_ability   530 non-null    object
#  11  hp               1025 non-null   int64
#  12  attack           1025 non-null   int64
#  13  defense          1025 non-null   int64
#  14  sp_atk           1025 non-null   int64
#  15  sp_def           1025 non-null   int64
#  16  speed            1025 non-null   int64
#  17  total            1025 non-null   int64
#  18  ev_yield         1025 non-null   object
#  19  catch_rate       1025 non-null   int64
#  20  base_friendship  1025 non-null   object
#  21  base_exp         1025 non-null   object
#  22  growth_rate      1025 non-null   object
#  23  egg_group1       1025 non-null   object
#  24  egg_group2       279 non-null    object
#  25  percent_male     870 non-null    float64
#  26  percent_female   870 non-null    float64
#  27  egg_cycles       1025 non-null   object
#  28  special_group    1025 non-null   object
# dtypes: float64(4), int64(10), object(15)
# memory usage: 232.4+ KB

# %%
## statistical summary for the continous data 
df.describe()
# Out:
#             dexnum   generation       height       weight           hp  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean    513.000000     4.741463     1.211610    66.981659    70.184390
# std     296.036315     2.633633     1.248167   121.275372    26.631054
# min       1.000000     1.000000     0.100000     0.100000     1.000000
# 25%     257.000000     3.000000     0.500000     8.500000    50.000000
# 50%     513.000000     5.000000     1.000000    28.000000    68.000000
# 75%     769.000000     7.000000     1.500000    70.000000    85.000000
# max    1025.000000     9.000000    20.000000   999.900000   255.000000
#
#             attack      defense       sp_atk       sp_def        speed  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean     77.521951    72.507317    70.080976    70.205854    67.186341
# std      29.782541    29.286972    29.658378    26.639329    28.717227
# min       5.000000     5.000000    10.000000    20.000000     5.000000
# 25%      55.000000    50.000000    47.000000    50.000000    45.000000
# 50%      75.000000    70.000000    65.000000    67.000000    65.000000
# 75%     100.000000    90.000000    90.000000    86.000000    88.000000
# max     181.000000   230.000000   173.000000   230.000000   200.000000
#
#              total   catch_rate  percent_male  percent_female
# count  1025.000000  1025.000000    870.000000      870.000000
# mean    427.686829    94.927805     54.928161       45.071839
# std     112.770735    76.108415     20.308375       20.308375
# min     175.000000     3.000000      0.000000        0.000000
# 25%     325.000000    45.000000     50.000000       50.000000
# 50%     450.000000    60.000000     50.000000       50.000000
# 75%     508.000000   140.000000     50.000000       50.000000
# max     720.000000   255.000000    100.000000      100.000000

# %%
## statistical summary for the catagorial data
df.describe(include='object')
# Out:
#              name  type1   type2          species  ability1     ability2  \
# count        1025   1025     526             1025      1025          858
# unique       1025     18      18              715       223          169
# top     Bulbasaur  Water  Flying  Paradox Pokémon  Levitate  Shell Armor
# freq            1    134     100               22        32           20
#
#        hidden_ability  ev_yield base_friendship base_exp  growth_rate  \
# count             530      1025            1025     1025         1025
# unique            125        48               9      181            6
# top        Weak Armor  2 Attack              50       62  Medium Fast
# freq               15       108             830       27          401
#
#        egg_group1 egg_group2 egg_cycles special_group
# count        1025        279       1025          1025
# unique         26         11         12             8
# top         Field    Water 1         20      Ordinary
# freq          182         77        539           857

# %%
#data type of each column 
df.dtypes
# Out:
# dexnum               int64
# name                object
# generation           int64
# type1               object
# type2               object
# species             object
# height             float64
# weight             float64
# ability1            object
# ability2            object
# hidden_ability      object
# hp                   int64
# attack               int64
# defense              int64
# sp_atk               int64
# sp_def               int64
# speed                int64
# total                int64
# ev_yield            object
# catch_rate           int64
# base_friendship     object
# base_exp            object
# growth_rate         object
# egg_group1          object
# egg_group2          object
# percent_male       float64
# percent_female     float64
# egg_cycles          object
# special_group       object
# dtype: object

# %%
#set the style for seaborn
sns.set(style="dark")

# %%
#Visualization 1: Distribution of Pokemon Generation
plt.figure(figsize=(10,6))
sns.countplot(x='generation',data=df, palette='plasma')
plt.title('Distribution of Pokemon Generations')
plt.xlabel('Generation')
plt.ylabel('Count')
plt.show()

# %%
#Visualization 2: Distribution of Pokemon Types 
plt.figure(figsize=(14,8))
type_counts= pd.concat([df['type1'],df['type2']]).value_counts()
sns.barplot(x=type_counts.index, y= type_counts.values, palette='inferno')
plt.title('Distribution of Pokemon Type')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %%
# Visualization 3: Pokemon Stats Distribution 
plt.figure(figsize=(14,6))
stats=['hp','attack','defense','sp_atk','sp_def','speed']
df[stats].boxplot()
plt.title('Distribution of Pokemon Stats')
plt.ylabel('Stat Value')
plt.show()

# %%
# Visualization 4: Total Stats by Generation
plt.figure(figsize=(10, 6))
sns.boxplot(x='generation', y='total', data=df, palette='viridis')
plt.title('Total Stats by Generation')
plt.xlabel('Generation')
plt.ylabel('Total Stats')
plt.show()

# %%
# Visualization 5: Height vs Weight
plt.figure(figsize=(10, 6))
sns.scatterplot(x='height', y='weight', data=df, hue='generation', palette='viridis', alpha=0.7)
plt.title('Height vs Weight of Pokémon')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %%
# Visualization 6: Correlation Heatmap of Stats
plt.figure(figsize=(10, 8))
corr = df[stats].corr()
sns.heatmap(corr, annot=True, cmap='viridis', fmt='.2f')
plt.title('Correlation Heatmap of Pokémon Stats')
plt.show()

# %%
# Visualization 7: Pokémon Speed Distribution by Type1
plt.figure(figsize=(14, 8))
sns.boxplot(x='type1', y='speed', data=df, palette='viridis')
plt.title('Pokémon Speed Distribution by Primary Type')
plt.xlabel('Primary Type')
plt.ylabel('Speed')
plt.xticks(rotation=90)
plt.show()

# %%
# Visualization 8: Base Experience by Generation
plt.figure(figsize=(10, 6))
df['base_exp'] = pd.to_numeric(df['base_exp'], errors='coerce')
sns.boxplot(x='generation', y='base_exp', data=df, palette='viridis')
plt.title('Base Experience by Generation')
plt.xlabel('Generation')
plt.ylabel('Base Experience')
plt.show()

# %%
# Visualization 9: Pokémon with Hidden Abilities by Generation
plt.figure(figsize=(10, 6))
hidden_ability_counts = df[df['hidden_ability'].notna()]['generation'].value_counts()
sns.barplot(x=hidden_ability_counts.index, y=hidden_ability_counts.values, palette='viridis')
plt.title('Pokémon with Hidden Abilities by Generation')
plt.xlabel('Generation')
plt.ylabel('Count')
plt.show()

# %%
# Visualization 10: Pokémon Weight Distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['weight'], bins=20, kde=True, color='purple')
plt.title('Distribution of Pokémon Weight')
plt.xlabel('Weight')
plt.ylabel('Count')
plt.show()

# %%
# Visualization 11: Pokémon Height Distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['height'], bins=20, kde=True, color='blue')
plt.title('Distribution of Pokémon Height')
plt.xlabel('Height')
plt.ylabel('Count')
plt.show()

# %%
# Visualization 12: Pokémon Total Stats by Type1
plt.figure(figsize=(14, 8))
sns.boxplot(x='type1', y='total', data=df, palette='viridis')
plt.title('Total Stats Distribution by Primary Type')
plt.xlabel('Primary Type')
plt.ylabel('Total Stats')
plt.xticks(rotation=90)
plt.show()
